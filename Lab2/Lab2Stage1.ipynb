# %% [markdown]
# # Storage Account
# ![JoshuaStorageAccount](/Volumes/dbr_dev/joshuandegwa7447/students/JoshuaStorageAccount.png)

# %% [markdown]
# # Key Vault
# ![JoshuaKeyvault](/Volumes/dbr_dev/joshuandegwa7447/students/JoshuaKeyvault.png)

# %% [markdown]
# # Databricks Workspace
# ![DatabricksWorkspace](/Volumes/dbr_dev/joshuandegwa7447/students/DatabricksWorkspace.png)
